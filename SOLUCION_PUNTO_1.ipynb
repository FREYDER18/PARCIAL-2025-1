# %% [markdown]
# <a href="https://colab.research.google.com/github/FREYDER18/PARCIAL-2025-1/blob/main/SOLUCION_PUNTO_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# punto 1
#
#
# 1.Se tiene un microprocesador de 5 bits con entrada análoga de
# -3.3 a 5 [v]. Diseñe el sistema de acondicionamiento y digitalización
# para la señal: \begin{equation}
# x(t) = 20 \sin\left(7t - \frac{\pi}{2}\right) - 3 \cos(5t) + 2 \cos(10t)
# \end{equation}Presente las simulaciones y gráficas de los procedimientos
# más representativos en un cuaderno de Python,
# incluyendo al menos dos períodos de la señaal estudiada.

# %% [markdown]
# Desarrollo Punto 1.

# %% [markdown]
# - Codigo punto 1.

# %%
import numpy as np
import matplotlib.pyplot as plt

v_min = -3.3  #voltaje minimo periodico
v_max = 5     #voltaje maximo periodico

t = np.linspace(0, 4*np.pi, 2000)# tiempo de simulacion


x = 20 * np.sin(7*t - np.pi/2) - 3 * np.cos(5*t) + 2 * np.cos(10*t) #señal original

# Calcula los valores máximos y mínimos de la señal original
x_max = np.max(x)
x_min = np.min(x)
#Calcular coeficientes de acondicionamiento
a = (5 - (-3.3)) / (x_max - x_min)
b = -3.3 - a * x_min

# Aplicar el acondicionamiento a la señal original
x_acond = a * x + b  # señal acondicionada

# Definir parámetros para la cuantización
bits = 5
niveles = 2**bits

delta = (v_max - (v_min)) / niveles  # Paso de cuantización (altura de cada escalón)

# Fórmula de cuantización
x_q = np.round((x_acond - v_min) / delta) * delta + v_min

#Graficar resultados
plt.figure(figsize=(10, 5))
plt.plot(t, x, label="Señal original", linewidth=1.5)
plt.plot(t, x_acond, label="Acondicionada", linestyle="--", linewidth=1.5)
plt.step(t, x_q, label="Cuantizada (5 bits)", where="mid", linewidth=0.5)
plt.xlabel("Tiempo [s]")
plt.ylabel("Amplitud [V]")
plt.title("Simulación de Acondicionamiento y Cuantización de x(t)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
